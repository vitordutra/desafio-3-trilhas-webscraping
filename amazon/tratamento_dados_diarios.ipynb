# %%
from datetime import date

data_atual = date.today()
print(data_atual)
# Out:
# 2021-10-22

# %%
import pandas as pd

# %%
df_phone_date = pd.read_csv('output/dataset_smartphone_date.csv',sep=';')

# %%
df_ntbk_date = pd.read_csv('output/dataset_notebook_date.csv',sep=';')

# %%
def arruma_df(dataset):
    for text  in dataset.Estrelas:
        if(type(text)==str):
            dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
            
    dataset['Preço'] = dataset['Preço'].apply(lambda x: x.replace('R$ ','')).apply(lambda x: x.replace('.','')).apply(lambda x: x.replace(',','.'))
    dataset.Estrelas = dataset.Estrelas.str.replace(',','.')
    dataset.TotalReviews = dataset.TotalReviews.apply(lambda x: str(x).replace('.',''))
    
    # Transformando dados em numericos
    colunas_numerica = ['Preço','Estrelas','TotalReviews']
    dataset[colunas_numerica]=dataset[colunas_numerica].apply(pd.to_numeric, errors='coerce')
    
    return dataset

# %%
arruma_df(df_phone_date)
# Out:
#                                             Descrição    Preço  Estrelas  \
# 0   Microfone de Lapela Celular Computador Câmera ...    29.87       0.0
# 1   Smartphone, Dual Card Dual Standby PRO + 6,72 ...   540.49       0.0
# 2   Moochy 3.5mm Com Fio Gaming Headset On-Ear Esp...    51.99       0.0
# 3   Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1249.90       4.8
# 4   Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   779.00       4.6
# ..                                                ...      ...       ...
# 60  Smartphone Xiaomi Redmi Note 10s 64gb/6gb Pebb...  1579.45       4.4
# 61   Smartphone Xiaomi Redmi 9A Versão Global - Verde   824.90       4.5
# 62  Note10 + Smartphone 5 polegadas Tela Digital D...   288.23       0.0
# 63  Rino3 Smartphone 5.0 em tela super cheia com 5...   307.05       0.0
# 64  Moochy 3.5mm Com Fio Gaming Headset On-Ear Esp...    50.99       0.0
#
#     TotalReviews                                                Url  \
# 0            0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 1            0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 2            0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 3        40946.0  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# 4         1390.0  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...
# ..           ...                                                ...
# 60         112.0  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# 61         613.0  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# 62           0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 63           0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 64           0.0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-22
# 1   2021-10-22
# 2   2021-10-22
# 3   2021-10-22
# 4   2021-10-22
# ..         ...
# 60  2021-10-22
# 61  2021-10-22
# 62  2021-10-22
# 63  2021-10-22
# 64  2021-10-22
#
# [65 rows x 6 columns]

# %%
df_phone_date.query("Preço > 500.00", inplace=True)
df_phone_date.reset_index(drop=True,inplace=True)
print(df_phone_date.shape)
df_phone_date.head()
# Out:
# (48, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Smartphone, Dual Card Dual Standby PRO + 6,72 ...   540.49       0.0
# 1  Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1249.90       4.8
# 2  Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   779.00       4.6
# 3  Smartphone Positivo Q20, 4Gb Ram, 128Gb, Tela ...   799.00       4.1
# 4  Smartphone Xiaomi Redmi Note 10 Versão Global ...  1720.00       4.6
#
#    TotalReviews                                                Url        Data
# 0           0.0  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-22
# 1       40946.0  https://www.amazon.com.br/Smartphone-Xiaomi-Re...  2021-10-22
# 2        1390.0  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...  2021-10-22
# 3         353.0  https://www.amazon.com.br/Smartphone-Positivo-...  2021-10-22
# 4        1330.0  https://www.amazon.com.br/Smartphone-Xiaomi-Re...  2021-10-22

# %%
arruma_df(df_ntbk_date)
# Out:
# <ipython-input-25-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   Bateria Para Notebook Dell Inspiron Mr90y N121...   245.90       0.0
# 1   Fonte Carregador P/Notebook Lenovo Ideapad 320...   105.33       4.3
# 2   Fonte Carregador P/Notebook Hp Pavilion G4-2214br    89.90       0.0
# 3   Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 4   Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
# ..                                                ...      ...       ...
# 57  Notebook Multilaser Legacy Cloud 14 Pol. 2GB 3...  1439.90       3.7
# 58            C3Tech NBC-50 Base para Notebook, Preto    58.90       4.6
# 59  Mouse Bluetooth para MacBook Pro/MacBook Air/L...    82.42       4.3
# 60  Mouse Bluetooth recarregável para Mac, laptop,...   119.35       3.4
# 61  SSD Solid State Drive 2,5" 128GB 240GB Desktop...   248.30       0.0
#
#     TotalReviews                                                Url  \
# 0              0  https://www.amazon.com.br/gp/slredirect/picass...
# 1           1320  https://www.amazon.com.br/gp/slredirect/picass...
# 2              0  https://www.amazon.com.br/gp/slredirect/picass...
# 3           2280  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# 4           4560  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# ..           ...                                                ...
# 57           560  https://www.amazon.com.br/Notebook-Multilaser-...
# 58          6517  https://www.amazon.com.br/Notebook-NBC-50BK-C3...
# 59           600  https://www.amazon.com.br/gp/slredirect/picass...
# 60            70  https://www.amazon.com.br/gp/slredirect/picass...
# 61             0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-22
# 1   2021-10-22
# 2   2021-10-22
# 3   2021-10-22
# 4   2021-10-22
# ..         ...
# 57  2021-10-22
# 58  2021-10-22
# 59  2021-10-22
# 60  2021-10-22
# 61  2021-10-22
#
# [62 rows x 6 columns]

# %%
df_ntbk_date.query("Preço > 1000", inplace=True)
df_ntbk_date.reset_index(drop=True, inplace=True)
print(df_ntbk_date.shape)
df_ntbk_date.head()
# Out:
# (44, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 1  Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
# 2  Notebook Lenovo Ultrafino ideapad S145 i5-1035...  3229.99       4.7
# 3  Notebook Lenovo Ultrafino ideapad S145, Intel ...  2999.00       4.6
# 4  SAMSUNG Chromebook SS 11.6 Intel DC 4GB 32GB X...  1629.90       4.5
#
#    TotalReviews                                                Url        Data
# 0          2280  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-22
# 1          4560  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-22
# 2           330  https://www.amazon.com.br/Lenovo-Ultrafino-S14...  2021-10-22
# 3          5240  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-22
# 4          2540  https://www.amazon.com.br/SAMSUNG-Chromebook-1...  2021-10-22

# %%
from datetime import date

df_phone_date.to_csv(f'output/diario/dados_smartphone_{date.today().day}.csv',sep=';',index=False)
df_ntbk_date.to_csv(f'output/diario/dados_notebook_{date.today().day}.csv',sep=';',index=False)
