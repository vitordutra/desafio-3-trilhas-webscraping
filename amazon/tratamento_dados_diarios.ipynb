# %%
from datetime import date

data_atual = date.today()
print(data_atual)
# Out:
# 2021-10-21

# %%
import pandas as pd

# %%
df_phone_date = pd.read_csv('output/dataset_smartphone_date.csv',sep=';')

# %%
df_ntbk_date = pd.read_csv('output/dataset_notebook_date.csv',sep=';')

# %%
def arruma_df(dataset):
    for text  in dataset.Estrelas:
        if(type(text)==str):
            dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
            
    dataset['Preço'] = dataset['Preço'].apply(lambda x: x.replace('R$ ','')).apply(lambda x: x.replace('.','')).apply(lambda x: x.replace(',','.'))
    dataset.Estrelas = dataset.Estrelas.str.replace(',','.')
    dataset.TotalReviews = dataset.TotalReviews.apply(lambda x: str(x).replace('.',''))
    
    # Transformando dados em numericos
    colunas_numerica = ['Preço','Estrelas','TotalReviews']
    dataset[colunas_numerica]=dataset[colunas_numerica].apply(pd.to_numeric, errors='coerce')
    
    return dataset

# %%
arruma_df(df_phone_date)
# Out:
# <ipython-input-5-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   Microfone de Lapela Celular Computador Câmera ...    29.87       0.0
# 1   Capa de telefone à prova d 'água para iPhone 6...   265.76       0.0
# 2   Smartphone Samsung Galaxy A31 Dual Chip, Andro...  1689.90       4.7
# 3   Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1209.99       4.8
# 4   Celular Smartphone Xiaomi Note 9 Forest Green ...  1494.90       4.7
# ..                                                ...      ...       ...
# 60  Xiaomi Redmi Note 10 4GB+64GB Versão global On...  1548.50       4.7
# 61  Smartphone LG K22+ , 3GB Memória, 64GB armazen...  1059.00       4.4
# 62  Rino3 Smartphone 5.0 em tela super cheia com 5...   307.05       0.0
# 63  Domary Mini teclado virtual de toque portátil ...   445.67       0.0
# 64  Houshome Fones de ouvido CK5 Fone de ouvido in...    66.77       0.0
#
#     TotalReviews                                                Url  \
# 0              0  https://www.amazon.com.br/gp/slredirect/picass...
# 1              0  https://www.amazon.com.br/gp/slredirect/picass...
# 2           3860  https://www.amazon.com.br/gp/slredirect/picass...
# 3          40941  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# 4            476  https://www.amazon.com.br/Celular-Smartphone-X...
# ..           ...                                                ...
# 60          2385  https://www.amazon.com.br/Xiaomi-Redmi-Note-Ve...
# 61          4020  https://www.amazon.com.br/Smartphone-LG-Mem%C3...
# 62             0  https://www.amazon.com.br/gp/slredirect/picass...
# 63             0  https://www.amazon.com.br/gp/slredirect/picass...
# 64             0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-21
# 1   2021-10-21
# 2   2021-10-21
# 3   2021-10-21
# 4   2021-10-21
# ..         ...
# 60  2021-10-21
# 61  2021-10-21
# 62  2021-10-21
# 63  2021-10-21
# 64  2021-10-21
#
# [65 rows x 6 columns]

# %%
df_phone_date.query("Preço > 500.00", inplace=True)
df_phone_date.reset_index(drop=True,inplace=True)
print(df_phone_date.shape)
df_phone_date.head()
# Out:
# (46, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Smartphone Samsung Galaxy A31 Dual Chip, Andro...  1689.90       4.7
# 1  Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1209.99       4.8
# 2  Celular Smartphone Xiaomi Note 9 Forest Green ...  1494.90       4.7
# 3  Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   779.00       4.6
# 4  Smartphone LG K22 , 2GB/32GB, Tela de 6, Câmer...   889.00       4.4
#
#    TotalReviews                                                Url        Data
# 0          3860  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-21
# 1         40941  https://www.amazon.com.br/Smartphone-Xiaomi-Re...  2021-10-21
# 2           476  https://www.amazon.com.br/Celular-Smartphone-X...  2021-10-21
# 3          1387  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...  2021-10-21
# 4          7100  https://www.amazon.com.br/Smartphone-LG-Proces...  2021-10-21

# %%
arruma_df(df_ntbk_date)
# Out:
# <ipython-input-12-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   Capa de Notebook 15,6 Polegadas Em Corino (Preta)    89.90       0.0
# 1   Base para Notebook, C3Tech, Nbc-100Bk, Bases e...    98.90       4.6
# 2   Base para Notebook C3Tech NBC-600BK até 17" Ga...   196.19       4.7
# 3   Notebook Lenovo Ultrafino ideapad S145 i5-1035...  3229.99       4.7
# 4   Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# ..                                                ...      ...       ...
# 58  Memória Impact HyperX, HX426S15IB2/8, de 8GB S...   349.98       4.8
# 59  Samsung Book E20 Intel® Dual-Core, Windows 10 ...  3029.00       4.2
# 60  MOCHILA EXECUTIVA 2 EM 1 COM ALÇA E RODINHAS P...   199.99       3.5
# 61  Mouse Bluetooth para MacBook Pro/MacBook Air/L...    78.57       4.3
# 62  Mouse Bluetooth recarregável para Mac, laptop,...   119.35       3.2
#
#     TotalReviews                                                Url  \
# 0              0  https://www.amazon.com.br/gp/slredirect/picass...
# 1           2002  https://www.amazon.com.br/gp/slredirect/picass...
# 2            250  https://www.amazon.com.br/gp/slredirect/picass...
# 3            310  https://www.amazon.com.br/Lenovo-Ultrafino-S14...
# 4           2250  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# ..           ...                                                ...
# 58          8480  https://www.amazon.com.br/Mem%C3%B3ria-laptop-...
# 59          6040  https://www.amazon.com.br/Samsung-Intel%C2%AE-...
# 60            20  https://www.amazon.com.br/gp/slredirect/picass...
# 61           600  https://www.amazon.com.br/gp/slredirect/picass...
# 62            60  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-21
# 1   2021-10-21
# 2   2021-10-21
# 3   2021-10-21
# 4   2021-10-21
# ..         ...
# 58  2021-10-21
# 59  2021-10-21
# 60  2021-10-21
# 61  2021-10-21
# 62  2021-10-21
#
# [63 rows x 6 columns]

# %%
df_ntbk_date.query("Preço > 1000", inplace=True)
df_ntbk_date.reset_index(drop=True, inplace=True)
print(df_ntbk_date.shape)
df_ntbk_date.head()
# Out:
# (45, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Notebook Lenovo Ultrafino ideapad S145 i5-1035...  3229.99       4.7
# 1  Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 2  Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
# 3  SAMSUNG Chromebook SS 11.6 Intel DC 4GB 32GB X...  1616.38       4.5
# 4  Notebook Ultra 14" Pentium 4GB 120GB SSD W10, ...  1439.10       4.1
#
#    TotalReviews                                                Url        Data
# 0           310  https://www.amazon.com.br/Lenovo-Ultrafino-S14...  2021-10-21
# 1          2250  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-21
# 2          4520  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-21
# 3          2530  https://www.amazon.com.br/SAMSUNG-Chromebook-1...  2021-10-21
# 4           360  https://www.amazon.com.br/Notebook-Ultra-Penti...  2021-10-21

# %%
from datetime import date

df_phone_date.to_csv(f'output/diario/dados_smartphone_{date.today().day}.csv',sep=';',index=False)
df_ntbk_date.to_csv(f'output/diario/dados_notebook_{date.today().day}.csv',sep=';',index=False)
