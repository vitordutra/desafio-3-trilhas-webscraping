# %%
from datetime import date

data_atual = date.today()
print(data_atual)
# Out:
# 2021-10-19

# %%
import pandas as pd

# %%
df_phone_date = pd.read_csv('output/dataset_smartphone_date.csv',sep=';')

# %%
df_ntbk_date = pd.read_csv('output/dataset_notebook_date.csv',sep=';')

# %%
def arruma_df(dataset):
    for text  in dataset.Estrelas:
        if(type(text)==str):
            dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
            
    dataset['Preço'] = dataset['Preço'].apply(lambda x: x.replace('R$ ','')).apply(lambda x: x.replace('.','')).apply(lambda x: x.replace(',','.'))
    dataset.Estrelas = dataset.Estrelas.str.replace(',','.')
    dataset.TotalReviews = dataset.TotalReviews.apply(lambda x: str(x).replace('.',''))
    
    # Transformando dados em numericos
    colunas_numerica = ['Preço','Estrelas','TotalReviews']
    dataset[colunas_numerica]=dataset[colunas_numerica].apply(pd.to_numeric, errors='coerce')
    
    return dataset

# %%
arruma_df(df_phone_date)
# Out:
# <ipython-input-10-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   Microfone de Lapela Celular Computador Câmera ...    29.87       0.0
# 1   Capa de telefone à prova d 'água para iPhone 6...   265.76       0.0
# 2   KKmoon Tripé de celular portátil Selfie extens...    72.99       0.0
# 3   Smartphone Positivo Q20, 4Gb Ram, 128Gb, Tela ...   799.00       4.1
# 4   Smartphone Poco X3 PRO 256gb 8gb RAM – Phantom...  1986.00       4.8
# ..                                                ...      ...       ...
# 60  Smartphone Xiaomi Redmi Note 8 4GB Ram Tela 6....  1190.71       4.7
# 61        Smartphone Redmi Note 8 4GB RAM 128GB Preto  1599.90       4.7
# 62  Miaoqian Suporte para tripé de viagem de mini ...   381.59       0.0
# 63  Tripé Para Celular e Camera, Tripé Profissiona...    79.90       4.6
# 64  Reno4 Pro Smartphone 5,8"Smartphone 512M + 4G ...   325.69       0.0
#
#     TotalReviews                                                Url  \
# 0              0  https://www.amazon.com.br/gp/slredirect/picass...
# 1              0  https://www.amazon.com.br/gp/slredirect/picass...
# 2              0  https://www.amazon.com.br/gp/slredirect/picass...
# 3           8700  https://www.amazon.com.br/Smartphone-Positivo-...
# 4           2396  https://www.amazon.com.br/Smartphone-Poco-PRO-...
# ..           ...                                                ...
# 60          3913  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# 61          6414  https://www.amazon.com.br/Smartphone-Redmi-Not...
# 62             0  https://www.amazon.com.br/gp/slredirect/picass...
# 63            60  https://www.amazon.com.br/gp/slredirect/picass...
# 64             0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-19
# 1   2021-10-19
# 2   2021-10-19
# 3   2021-10-19
# 4   2021-10-19
# ..         ...
# 60  2021-10-19
# 61  2021-10-19
# 62  2021-10-19
# 63  2021-10-19
# 64  2021-10-19
#
# [65 rows x 6 columns]

# %%
df_phone_date.query("Preço > 500.00", inplace=True)
df_phone_date.reset_index(drop=True,inplace=True)
print(df_phone_date.shape)
df_phone_date.head()
# Out:
# (45, 6)
#                                            Descrição   Preço  Estrelas  \
# 0  Smartphone Positivo Q20, 4Gb Ram, 128Gb, Tela ...   799.0       4.1
# 1  Smartphone Poco X3 PRO 256gb 8gb RAM – Phantom...  1986.0       4.8
# 2  Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   799.0       4.6
# 3  Smartphone ASUS Zenfone Max Pro M2, 6GB 64GB, ...  1299.0       4.5
# 4  Smartphone Xiaomi Redmi 9 India 64GB 4GB RAM T...  1115.0       4.3
#
#    TotalReviews                                                Url        Data
# 0          8700  https://www.amazon.com.br/Smartphone-Positivo-...  2021-10-19
# 1          2396  https://www.amazon.com.br/Smartphone-Poco-PRO-...  2021-10-19
# 2          1385  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...  2021-10-19
# 3          4540  https://www.amazon.com.br/Zenfone-Max-Pro-M2-6...  2021-10-19
# 4          1050  https://www.amazon.com.br/Smartphone-Xiaomi-Re...  2021-10-19

# %%
arruma_df(df_ntbk_date)
# Out:
# <ipython-input-10-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   MOCHILA EXECUTIVA 2 EM 1 COM ALÇA E RODINHAS P...   199.99       3.5
# 1   Notebook Gateway Ultra Slim Laptop, 14,1 poleg...  6173.47       0.0
# 2   Notebook Gateway Ultra Slim Laptop, 14,1" IPS ...  5437.65       0.0
# 3   Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 4   Notebook Lenovo Ultrafino ideapad S145 i5-1035...  3229.99       4.7
# ..                                                ...      ...       ...
# 57            C3Tech NBC-50 Base para Notebook, Preto    59.31       4.6
# 58  Notebook ASUS X515JF-EJ153T INTEL CORE I5 1035...  4699.00       5.0
# 59  Notebook Gateway ultrafino para laptop, 14,1 p...  4962.78       0.0
# 60  amuzer SSD Mobile Solid State Drive | Unidade ...   504.13       0.0
# 61  amuzer SSD Mobile Solid State Drive | Disco ex...   258.19       0.0
#
#     TotalReviews                                                Url  \
# 0             20  https://www.amazon.com.br/gp/slredirect/picass...
# 1              0  https://www.amazon.com.br/gp/slredirect/picass...
# 2              0  https://www.amazon.com.br/gp/slredirect/picass...
# 3           2170  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# 4            290  https://www.amazon.com.br/Lenovo-Ultrafino-S14...
# ..           ...                                                ...
# 57          6492  https://www.amazon.com.br/Notebook-NBC-50BK-C3...
# 58            50  https://www.amazon.com.br/Notebook-ASUS-X515JF...
# 59             0  https://www.amazon.com.br/gp/slredirect/picass...
# 60             0  https://www.amazon.com.br/gp/slredirect/picass...
# 61             0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-19
# 1   2021-10-19
# 2   2021-10-19
# 3   2021-10-19
# 4   2021-10-19
# ..         ...
# 57  2021-10-19
# 58  2021-10-19
# 59  2021-10-19
# 60  2021-10-19
# 61  2021-10-19
#
# [62 rows x 6 columns]

# %%
df_ntbk_date.query("Preço > 1000", inplace=True)
df_ntbk_date.reset_index(drop=True, inplace=True)
print(df_ntbk_date.shape)
df_ntbk_date.head()
# Out:
# (47, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Notebook Gateway Ultra Slim Laptop, 14,1 poleg...  6173.47       0.0
# 1  Notebook Gateway Ultra Slim Laptop, 14,1" IPS ...  5437.65       0.0
# 2  Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 3  Notebook Lenovo Ultrafino ideapad S145 i5-1035...  3229.99       4.7
# 4  Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
#
#    TotalReviews                                                Url        Data
# 0             0  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-19
# 1             0  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-19
# 2          2170  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-19
# 3           290  https://www.amazon.com.br/Lenovo-Ultrafino-S14...  2021-10-19
# 4          4450  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-19

# %%
from datetime import date

df_phone_date.to_csv(f'output/diario/dados_smartphone_{date.today().day}.csv',sep=';',index=False)
df_ntbk_date.to_csv(f'output/diario/dados_notebook_{date.today().day}.csv',sep=';',index=False)
