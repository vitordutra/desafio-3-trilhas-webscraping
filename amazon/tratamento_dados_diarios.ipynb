# %%
from datetime import date

data_atual = date.today()
print(data_atual)
# Out:
# 2021-10-27

# %%
import pandas as pd

# %%
df_phone_date = pd.read_csv('output/dataset_smartphone_date.csv',sep=';')

# %%
df_ntbk_date = pd.read_csv('output/dataset_notebook_date.csv',sep=';')

# %%
def arruma_df(dataset):
    for text  in dataset.Estrelas:
        if(type(text)==str):
            dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
            
    dataset['Preço'] = dataset['Preço'].apply(lambda x: x.replace('R$ ','')).apply(lambda x: x.replace('.','')).apply(lambda x: x.replace(',','.'))
    dataset.Estrelas = dataset.Estrelas.str.replace(',','.')
    dataset.TotalReviews = dataset.TotalReviews.apply(lambda x: str(x).replace('.',''))
    
    # Transformando dados em numericos
    colunas_numerica = ['Preço','Estrelas','TotalReviews']
    dataset[colunas_numerica]=dataset[colunas_numerica].apply(pd.to_numeric, errors='coerce')
    
    return dataset

# %%
arruma_df(df_phone_date)
# Out:
# <ipython-input-5-20f019420312>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.Estrelas[dataset.Estrelas == text] = text.split()[0]
#                                             Descrição    Preço  Estrelas  \
# 0   DJI Estabilizador de gimbal para smartphone OM...  1650.00       3.0
# 1   Smartphone, Dual Card Dual Standby PRO + 6,72 ...   677.49       0.0
# 2   Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   829.00       4.6
# 3   Smartphone LG K22 , 2GB/32GB, Tela de 6, Câmer...   889.00       4.4
# 4   Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1213.80       4.8
# ..                                                ...      ...       ...
# 59  Smartphone Samsung Galaxy A12 Vermelho 64GB, T...  1099.90       4.7
# 60  Smartphone Multilaser G Max 4G 32GB Tela 6.0 P...   645.00       4.1
# 61  Microfone de lapela SOLESTE de 3,5 mm Microfon...   157.92       0.0
# 62  Suporte de Mesa para Celular Ajustável, Articu...    59.90       5.0
# 63  Note10 + Smartphone 5 polegadas Tela Digital D...   287.75       0.0
#
#     TotalReviews                                                Url  \
# 0            220  https://www.amazon.com.br/gp/slredirect/picass...
# 1              0  https://www.amazon.com.br/gp/slredirect/picass...
# 2           1399  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...
# 3           7120  https://www.amazon.com.br/Smartphone-LG-Proces...
# 4          40984  https://www.amazon.com.br/Smartphone-Xiaomi-Re...
# ..           ...                                                ...
# 59           240  https://www.amazon.com.br/Smartphone-Vermelho-...
# 60           270  https://www.amazon.com.br/Smartphone-Multilase...
# 61             0  https://www.amazon.com.br/gp/slredirect/picass...
# 62            10  https://www.amazon.com.br/gp/slredirect/picass...
# 63             0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-27
# 1   2021-10-27
# 2   2021-10-27
# 3   2021-10-27
# 4   2021-10-27
# ..         ...
# 59  2021-10-27
# 60  2021-10-27
# 61  2021-10-27
# 62  2021-10-27
# 63  2021-10-27
#
# [64 rows x 6 columns]

# %%
df_phone_date.query("Preço > 500.00", inplace=True)
df_phone_date.reset_index(drop=True,inplace=True)
print(df_phone_date.shape)
df_phone_date.head()
# Out:
# (42, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  DJI Estabilizador de gimbal para smartphone OM...  1650.00       3.0
# 1  Smartphone, Dual Card Dual Standby PRO + 6,72 ...   677.49       0.0
# 2  Smartphone LG K41S 32GB, RAM de 3GB, Tela de 6...   829.00       4.6
# 3  Smartphone LG K22 , 2GB/32GB, Tela de 6, Câmer...   889.00       4.4
# 4  Smartphone Xiaomi Redmi Note 8 4RAM 64GB Tela ...  1213.80       4.8
#
#    TotalReviews                                                Url        Data
# 0           220  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-27
# 1             0  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-27
# 2          1399  https://www.amazon.com.br/Smartphone-LG-Qu%C3%...  2021-10-27
# 3          7120  https://www.amazon.com.br/Smartphone-LG-Proces...  2021-10-27
# 4         40984  https://www.amazon.com.br/Smartphone-Xiaomi-Re...  2021-10-27

# %%
arruma_df(df_ntbk_date)
# Out:
#                                             Descrição    Preço  Estrelas  \
# 0   HD p/Notebook 320Gb Toshiba MK3261GSYN (MK3261...   122.00       4.6
# 1   Notebook Positivo Stilo Colors XCI3634 Intel® ...  1469.90       0.0
# 2   Notebook Positivo Stilo ONE XCI3630 Intel® Cel...  1499.90       4.0
# 3   Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 4   Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
# ..                                                ...      ...       ...
# 57  Notebook Dell Inspiron i15-3501-A80S 15.6" HD ...  5579.10       5.0
# 58  Notebook Gamer Legion 5i i7-10750H 16GB 512GB ...  9199.00       4.7
# 59  Notebook Positivo Stilo One XC5631 Intel® Pent...  2029.90       1.0
# 60  Notebook Positivo Stilo One XC3550 Intel Atom ...  1699.90       3.4
# 61  Notebook Positivo Stilo One XC5630 Intel® Pent...  2029.90       0.0
#
#     TotalReviews                                                Url  \
# 0            NaN  https://www.amazon.com.br/gp/slredirect/picass...
# 1            0.0  https://www.amazon.com.br/gp/slredirect/picass...
# 2            NaN  https://www.amazon.com.br/gp/slredirect/picass...
# 3            NaN  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# 4            NaN  https://www.amazon.com.br/Notebook-Lenovo-Ultr...
# ..           ...                                                ...
# 57           NaN  https://www.amazon.com.br/Notebook-Dell-Inspir...
# 58           NaN  https://www.amazon.com.br/Notebook-Legion-i7-1...
# 59           NaN  https://www.amazon.com.br/gp/slredirect/picass...
# 60           NaN  https://www.amazon.com.br/gp/slredirect/picass...
# 61           0.0  https://www.amazon.com.br/gp/slredirect/picass...
#
#           Data
# 0   2021-10-27
# 1   2021-10-27
# 2   2021-10-27
# 3   2021-10-27
# 4   2021-10-27
# ..         ...
# 57  2021-10-27
# 58  2021-10-27
# 59  2021-10-27
# 60  2021-10-27
# 61  2021-10-27
#
# [62 rows x 6 columns]

# %%
df_ntbk_date.query("Preço > 1000", inplace=True)
df_ntbk_date.reset_index(drop=True, inplace=True)
print(df_ntbk_date.shape)
df_ntbk_date.head()
# Out:
# (48, 6)
#                                            Descrição    Preço  Estrelas  \
# 0  Notebook Positivo Stilo Colors XCI3634 Intel® ...  1469.90       0.0
# 1  Notebook Positivo Stilo ONE XCI3630 Intel® Cel...  1499.90       4.0
# 2  Notebook Lenovo Ultrafino IdeaPad S145, AMD Ry...  2999.00       4.5
# 3  Notebook Lenovo Ultrafino IdeaPad 3i, Intel Co...  3324.99       4.7
# 4  Notebook Lenovo Ultrafino ideapad S145, Intel ...  2999.00       4.6
#
#    TotalReviews                                                Url        Data
# 0           0.0  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-27
# 1           NaN  https://www.amazon.com.br/gp/slredirect/picass...  2021-10-27
# 2           NaN  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-27
# 3           NaN  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-27
# 4           NaN  https://www.amazon.com.br/Notebook-Lenovo-Ultr...  2021-10-27

# %%
from datetime import date

df_phone_date.to_csv(f'output/diario/dados_smartphone_{date.today().day}.csv',sep=';',index=False)
df_ntbk_date.to_csv(f'output/diario/dados_notebook_{date.today().day}.csv',sep=';',index=False)
