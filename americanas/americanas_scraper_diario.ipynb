# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from datetime import date
import time

# %%
def scraper(pesquisa):
    
    url = f'https://www.americanas.com.br/busca/{pesquisa}?limit=75&offset=0'
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(url)
    time.sleep(1)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    itens = soup.body.find('div',{'id':'root'}).find('div',{'class':'grid__StyledGrid-sc-1man2hx-0 iFeuoP'}).findAll('div',{'class':'col__StyledCol-sc-1snw5v3-0 epVkvq src__ColGridItem-sc-122lblh-0 bvfSKS'})

    # 'https://www.americanas.com.br' + itens[0].a.get("href")

    cards = []
    for iten in itens:
        card = {}
        card['Descrição'] = iten.h3.text
        card['Preço'] = iten.find('span',{'class':'src__Text-sc-154pg0p-0 src__Price-sc-1k0ejj6-7 dvVMTs'}).text
        # card['Preço Promocional'] = iten.find('span',{'class':'src__Text-sc-154pg0p-0 src__PromotionalPrice-sc-1k0ejj6-8 gxxqGt'}).text
        # card['Url'] = 'https://www.americanas.com.br' + itens[0].a.get("href")
        card['Data'] = date.today()
        cards.append(card)
        
    dataset = pd.DataFrame(cards)
    dataset.to_csv(f'output/diario/dataset_{pesquisa}_{date.today().day}.csv'.replace(' ','_'), index = False, encoding = 'utf-8-sig', sep=";")

# %%
scraper('smartphone')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\Felip\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
dataset = pd.read_csv(f'output/diario/dataset_smartphone_{date.today().day}.csv', sep=';')
dataset.dropna(inplace=True)
dataset.reset_index(drop=True, inplace=True)
dataset
# Out:
#                                             Descrição        Preço        Data
# 0   Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...  R$ 1.099,00  2021-10-22
# 1   Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...  R$ 1.099,00  2021-10-22
# 2   Smartphone Motorola Moto G30 128GB 4G Wi-Fi Te...  R$ 1.619,82  2021-10-22
# 3   Smartphone Motorola Moto E7 Power 32GB 4G Wi-F...    R$ 799,00  2021-10-22
# 4   Smartphone Samsung Galaxy A02s 32GB 4G Wi-Fi T...    R$ 909,00  2021-10-22
# 5   Smartphone Samsung Galaxy A32 128GB 4G Wi-Fi T...  R$ 1.490,00  2021-10-22
# 6   Smartphone Samsung Galaxy A32 128GB 4G Wi-Fi T...  R$ 1.490,00  2021-10-22
# 7   Smartphone Samsung Galaxy M62 128GB 8GB RAM Ba...  R$ 1.899,00  2021-10-22
# 8   Smartphone Samsung Galaxy A12 64GB 4G Wi-Fi Te...  R$ 1.199,00  2021-10-22
# 9   Smartphone Samsung Galaxy M62 128GB 8GB RAM Ba...  R$ 1.899,00  2021-10-22
# 10  Smartphone Samsung Galaxy A02 32GB 4G Wi-Fi Te...    R$ 759,90  2021-10-22
# 37  Smartphone Samsung Galaxy A03s 64GB 4G Wi-Fi T...    R$ 930,05  2021-10-22
# 38  Smartphone LG K62 64GB 4G Wi-Fi Tela 6.6'' Dua...    R$ 989,00  2021-10-22
# 39  Smartphone Motorola Moto E6i 32GB 4G Wi-Fi Tel...    R$ 705,90  2021-10-22
# 40  Smartphone Realme C25 128GB 4G Wi-Fi Tela 6.5'...  R$ 1.149,00  2021-10-22
# 41  Smartphone Samsung Galaxy A52 128GB 4G Wi-Fi T...  R$ 2.199,00  2021-10-22
# 42  Smartphone Motorola Moto G9 Play 64GB 4G Wi-Fi...  R$ 1.199,00  2021-10-22
# 43  Smartphone Samsung Galaxy Note 20 256GB 5G Wi-...  R$ 3.874,00  2021-10-22
# 44  Smartphone LG K22 32GB 4G Wi-Fi Tela 6.2'' Dua...    R$ 697,99  2021-10-22
# 45  Smartphone Samsung Galaxy S21 Ultra 256GB 5G W...  R$ 6.699,00  2021-10-22
# 46  Smartphone Motorola Moto G60s 128GB 4G Wi-Fi T...  R$ 1.877,00  2021-10-22
# 47  Smartphone LG K41s 32GB 4G Wi-Fi Tela 6.5'' Du...    R$ 825,00  2021-10-22
# 48  Smartphone Samsung Galaxy A52 128GB 4G Wi-Fi T...  R$ 2.199,00  2021-10-22

# %%
scraper('notebook')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\Felip\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
dataset = pd.read_csv(f'output/diario/dataset_notebook_{date.today().day}.csv', sep=';')
dataset.dropna(inplace=True)
dataset.reset_index(drop=True, inplace=True)
dataset
# Out:
#                                             Descrição        Preço        Data
# 0   Notebook Lenovo Ultrafino Ideapad S145 AMD Ryz...  R$ 3.047,17  2021-10-22
# 1   Notebook Samsung Book Intel Celeron-6305 4GB 5...  R$ 2.239,00  2021-10-22
# 2   Notebook Samsung Book Intel Core i5-1135G7 8GB...  R$ 3.689,00  2021-10-22
# 3   Notebook Dell Inspiron I15-3501-A25P Intel Cor...  R$ 3.099,99  2021-10-22
# 4   Notebook Lenovo Ultrafino Ideapad 3i Intel Cor...  R$ 3.499,99  2021-10-22
# ..                                                ...          ...         ...
# 65  Notebook 2 em 1 Dell Inspiron 5406-M10S 14 Tou...  R$ 4.699,00  2021-10-22
# 66  Notebook Gamer Dell G15-a0500-MM10P 15.6 fhd a...  R$ 6.799,00  2021-10-22
# 67  Notebook Asus X515JA-EJ592T Intel Core i5-1035...  R$ 3.699,99  2021-10-22
# 68  Notebook Gamer Dell G5-5590-A55P 9ª Intel Core...  R$ 7.209,84  2021-10-22
# 69  Notebook Samsung Flash F30 Intel Celeron 4GB 6...  R$ 2.699,00  2021-10-22
#
# [70 rows x 3 columns]
