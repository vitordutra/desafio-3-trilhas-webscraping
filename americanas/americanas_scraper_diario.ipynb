# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from datetime import date
import time

# %%
def scraper(pesquisa):
    
    url = f'https://www.americanas.com.br/busca/{pesquisa}?limit=75&offset=0'
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(url)
    time.sleep(5)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    itens = soup.body.find('div',{'id':'root'}).find('div',{'class':'grid__StyledGrid-sc-1man2hx-0 iFeuoP'}).findAll('div',{'class':'col__StyledCol-sc-1snw5v3-0 epVkvq src__ColGridItem-sc-122lblh-0 bvfSKS'})

    # 'https://www.americanas.com.br' + itens[0].a.get("href")

    cards = []
    for iten in itens:
        card = {}
        card['Descrição'] = iten.h3.text
        card['Preço'] = iten.find('span',{'class':'src__Text-sc-154pg0p-0 src__Price-sc-1k0ejj6-7 dvVMTs'}).text
        # card['Preço Promocional'] = iten.find('span',{'class':'src__Text-sc-154pg0p-0 src__PromotionalPrice-sc-1k0ejj6-8 gxxqGt'}).text
        # card['Url'] = 'https://www.americanas.com.br' + itens[0].a.get("href")
        card['Data'] = date.today()
        cards.append(card)
        
    dataset = pd.DataFrame(cards)
    dataset.to_csv(f'output/diario/dataset_{pesquisa}_{date.today().day}.csv'.replace(' ','_'), index = False, encoding = 'utf-8-sig', sep=";")

# %%
scraper('smartphone')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\Felip\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
dataset = pd.read_csv(f'output/diario/dataset_smartphone_{date.today().day}.csv', sep=';')
dataset.dropna(inplace=True)
dataset.reset_index(drop=True, inplace=True)
dataset
# Out:
#                                             Descrição        Preço        Data
# 0   Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...  R$ 1.279,00  2021-10-27
# 1   Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...  R$ 1.078,00  2021-10-27
# 2   Smartphone Samsung Galaxy A12 64GB 4G Wi-Fi Te...  R$ 1.076,67  2021-10-27
# 3   Smartphone Samsung Galaxy A32 128GB 4G Wi-Fi T...  R$ 1.729,00  2021-10-27
# 4   Smartphone Samsung Galaxy M62 128GB 8GB RAM Ba...  R$ 1.999,00  2021-10-27
# 5   Smartphone Samsung Galaxy A32 128GB 4G Wi-Fi T...  R$ 1.479,00  2021-10-27
# 6   Smartphone Motorola Moto E7 Power 32GB 4G Wi-F...    R$ 799,00  2021-10-27
# 7   Smartphone Samsung Galaxy M62 128GB 8GB RAM Ba...  R$ 1.804,05  2021-10-27
# 8   Smartphone Samsung Galaxy A02 32GB 4G Wi-Fi Te...    R$ 739,90  2021-10-27
# 9   Smartphone Motorola Moto E7 32GB 4G Wi-Fi Tela...    R$ 813,04  2021-10-27
# 10  Smartphone Samsung Galaxy A02s 32GB 4G Wi-Fi T...    R$ 939,00  2021-10-27
# 36  Smartphone Samsung Galaxy A03s 64GB 4G Wi-Fi T...    R$ 979,00  2021-10-27
# 37  Smartphone Motorola Moto G60s 128GB 4G Wi-Fi T...  R$ 1.867,00  2021-10-27
# 38  Smartphone Samsung Galaxy S20 Fe 256GB 4G Wi-F...  R$ 2.979,00  2021-10-27
# 39  Smartphone Realme C25 128GB 4G Wi-Fi Tela 6.5'...  R$ 1.149,00  2021-10-27
# 40  Smartphone Samsung Galaxy Note 20 Ultra 256GB ...  R$ 5.423,00  2021-10-27
# 41  Smartphone Samsung Galaxy S20 Fe 256GB 4G Wi-F...  R$ 2.979,00  2021-10-27
# 42  Smartphone Samsung Galaxy A72 128GB 4G Wi-Fi T...  R$ 2.698,80  2021-10-27
# 43  Smartphone Samsung Galaxy S21 Ultra 256GB 5G W...  R$ 7.329,00  2021-10-27
# 44  Smartphone LG K41s 32GB 4G Wi-Fi Tela 6.5'' Du...    R$ 810,00  2021-10-27
# 45  Smartphone Moto G60 128GB 4G Wi-Fi Tela 6.8'' ...  R$ 2.409,00  2021-10-27
# 46  Smartphone Samsung Galaxy A52 128GB 4G Wi-Fi T...  R$ 2.179,00  2021-10-27
# 47  Smartphone Samsung Galaxy S21 128GB 5G Wi-Fi T...  R$ 4.329,00  2021-10-27

# %%
scraper('notebook')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\Felip\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
dataset = pd.read_csv(f'output/diario/dataset_notebook_{date.today().day}.csv', sep=';')
dataset.dropna(inplace=True)
dataset.reset_index(drop=True, inplace=True)
dataset
# Out:
#                                             Descrição        Preço        Data
# 0   Notebook Samsung Book Intel Core i5-1135G7 8GB...  R$ 3.789,00  2021-10-27
# 1   Notebook Samsung Book Intel Celeron-6305 4GB 5...  R$ 2.239,00  2021-10-27
# 2   Notebook Positivo 2 em 1 Duo C464C Intel Celer...  R$ 1.660,88  2021-10-27
# 3   Notebook Acer Aspire 5 A515-54-50BT Intel Core...  R$ 3.990,06  2021-10-27
# 4   Notebook Ultra UB320 Intel Pentium-J3710 4GB 1...  R$ 1.750,03  2021-10-27
# ..                                                ...          ...         ...
# 58  Notebook Dell Inspiron i3501-M10P 15.6" HD 11ª...  R$ 3.199,00  2021-10-27
# 59  Notebook Samsung Flash F30 Intel Celeron 4GB 6...  R$ 2.398,52  2021-10-27
# 60  Notebook Ultrafino Dell Inspiron i5502-M40S 15...  R$ 7.499,00  2021-10-27
# 61  Kit Notebook Dell Inspiron i3501-M10PC 15.6" H...  R$ 3.199,00  2021-10-27
# 62  Notebook Gamer Dell G5-5590-A55P 9ª Intel Core...  R$ 7.208,49  2021-10-27
#
# [63 rows x 3 columns]
