# %% [markdown]
# ## Importando as LIBS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Carregando e visualizando os dados

# %%
df_notebook = pd.read_csv("./output/dataset_notebook.csv", sep=";")
df_smartphone = pd.read_csv("./output/dataset_smartphone.csv", sep=";")
df_smarttv= pd.read_csv("./output/dataset_smart_tv.csv", sep=";")

# %%
# NOTEBOOK
df_notebook.head()
# Out:
#                                            Descrição  TotalReviews    Preço  \
# 0  Notebook Lenovo Ultrafino Ideapad 3i Intel Cor...            54  3562.49
# 1  Notebook Samsung Book Intel Celeron-6305 4GB 5...            90  2098.70
# 2  Notebook Lenovo Ultrafino Ideapad S145 AMD Ryz...             7  2952.57
# 3  Notebook Samsung Book Intel Core i5-1135G7 8GB...             0  3544.81
# 4  Notebook Positivo Motion Q464C Intel Atom Z835...            73  1424.99
#
#                                                  Url        Loja
# 0  https://www.americanas.com.br/produto/31713181...  Americanas
# 1  https://www.americanas.com.br/produto/30813587...  Americanas
# 2  https://www.americanas.com.br/produto/33836426...  Americanas
# 3  https://www.americanas.com.br/produto/30813588...  Americanas
# 4  https://www.americanas.com.br/produto/28311550...  Americanas

# %%
df_notebook.count()
# Out:
# Descrição       350
# TotalReviews    350
# Preço           350
# Url             350
# Loja            350
# dtype: int64

# %%
# Smartphone
df_smartphone.head()
# Out:
#                                            Descrição  TotalReviews    Preço  \
# 0  Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...           272   988.99
# 1  Smartphone Motorola Moto G10 64GB 4G Wi-Fi Tel...           278   988.99
# 2  Smartphone Motorola Moto E7 Power 32GB 4G Wi-F...           121   645.05
# 3  Smartphone Moto G20 64GB 4G Wi-Fi Tela 6.5'' D...            94  1049.00
# 4  Smartphone Motorola Moto G30 128GB 4G Wi-Fi Te...             0  1310.05
#
#                                                  Url        Loja
# 0  https://www.americanas.com.br/produto/29172687...  Americanas
# 1  https://www.americanas.com.br/produto/29172691...  Americanas
# 2  https://www.americanas.com.br/produto/29104387...  Americanas
# 3  https://www.americanas.com.br/produto/31713187...  Americanas
# 4  https://www.americanas.com.br/produto/29172650...  Americanas

# %%
df_smartphone.count()
# Out:
# Descrição       346
# TotalReviews    346
# Preço           346
# Url             346
# Loja            346
# dtype: int64

# %%
df_smarttv.head()
# Out:
#                                            Descrição  TotalReviews    Preço  \
# 0  Samsung Smart TV LED 40'' Tizen FHD 40T5300 20...           656  2199.99
# 1  Smart TV LED 43'' Full HD Philco PTV43E10N5SF ...           210  1899.99
# 2  Smart TV LED 32'' Samsung Tizen HD 32T4300 202...           839  1599.99
# 3  Smart TV LG 32" HD 32LM627B Wi-Fi Bluetooth HD...            56  1599.99
# 4  Smart TV LED 32" Philco PTV32G52S HD e Áudio D...             0  1399.99
#
#                                                  Url        Loja
# 0  https://www.americanas.com.br/produto/17043510...  Americanas
# 1  https://www.americanas.com.br/produto/26807507...  Americanas
# 2  https://www.americanas.com.br/produto/16180745...  Americanas
# 3  https://www.americanas.com.br/produto/33970398...  Americanas
# 4  https://www.americanas.com.br/produto/13221193...  Americanas

# %% [markdown]
# ### Verificação de Valores Nulos: NaN

# %%
print("Valores nulos notebooks: ", df_notebook.isnull().sum().sum())
# Out:
# Valores nulos notebooks:  0

# %% [markdown]
# **Sem valores nulos, isso foi graça ao tratamento prévio da obtenção dos dados**

# %%
print("Valores nulos smatphones: ", df_smartphone.isnull().sum().sum())
# Out:
# Valores nulos smatphones:  0

# %%
print("Valores nulos smatphones: ", df_smarttv.isnull().sum().sum())
# Out:
# Valores nulos smatphones:  0

# %% [markdown]
# ### Estatística Descritiva

# %%
print("Objeto: Notebbok")
df_notebook.describe().round(2)
# Out:
# Objeto: Notebbok
#        TotalReviews     Preço
# count        350.00    350.00
# mean           7.07   3874.50
# std           22.30   2671.35
# min            0.00      0.00
# 25%            0.00   2406.73
# 50%            0.00   3589.00
# 75%            2.00   4999.00
# max          161.00  33029.10

# %% [markdown]
# **Um preço igual a 0 pode ser um erro na obtenção dos dados**

# %%
print("Visualizando dado notebook preço == 0")
df_notebook.query("Preço == 0")
# Out:
# Visualizando dado notebook preço == 0
#                                              Descrição  TotalReviews  Preço  \
# 83   Notebook Samsung Book X40 10ª Intel Core i5 8G...            66    0.0
# 281  Notebook Samsung Essentials E30, Intel Core I3...             0    0.0
#
#                                                    Url        Loja
# 83   https://www.americanas.com.br/produto/17725510...  Americanas
# 281  https://www.americanas.com.br/produto/29817989...  Americanas

# %%
# Smartphone
print("Objeto: Smartphone")
df_smartphone.describe().round(2)
# Out:
# Objeto: Smartphone
#        TotalReviews    Preço
# count        346.00   346.00
# mean          94.28  1660.62
# std          187.90  1224.50
# min            0.00     0.00
# 25%            1.00   872.58
# 50%           13.00  1352.12
# 75%           88.25  2052.02
# max         1899.00  8118.37

# %%
print("Visualizando dado smartphone preço == 0")
df_smartphone.query("Preço == 0")
# Out:
# Visualizando dado smartphone preço == 0
#                                              Descrição  TotalReviews  Preço  \
# 312  Smartphone Multilaser P9076 Up Play Dual Chip ...             0    0.0
# 320           Celular Multilaser Vita Flip Dual - P902             0    0.0
#
#                                                    Url        Loja
# 312  https://www.americanas.com.br/produto/28062553...  Americanas
# 320  https://www.americanas.com.br/produto/35065370...  Americanas

# %%
# Smart TV
print("Objeto: SMART TV")
df_smarttv.describe().round(2)
# Out:
# Objeto: SMART TV
#        TotalReviews     Preço
# count        349.00    349.00
# mean          26.14   4644.02
# std          102.32   5684.04
# min            0.00      0.00
# 25%            0.00   1699.99
# 50%            0.00   3068.01
# 75%            2.00   5149.61
# max          853.00  49999.99

# %%
print("Visualizando dado Smart TV preço == 0")
df_smarttv.query("Preço == 0")
# Out:
# Visualizando dado Smart TV preço == 0
#                                              Descrição  TotalReviews  Preço  \
# 56   Smart TV LED 32" 32lk615bpsb HD com Conversor ...           153    0.0
# 181  Smart TV 4K LED Philips 55' 55PUG6654/78, uhd,...             2    0.0
#
#                                                    Url        Loja
# 56   https://www.americanas.com.br/produto/13372070...  Americanas
# 181  https://www.americanas.com.br/produto/17560382...  Americanas

# %% [markdown]
# ## Histograma: Distribuição de Frequencias

# %%
def plotarHistograma(df, titulo):
    sns.set(style="darkgrid")
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    histplot = sns.histplot(data=df, x='Preço', linewidth=1, bins=30, kde=True)
    histplot.axes.set_title(f"Histograma de Preços dos {titulo}", fontsize=16)
    histplot.set_xlabel("Preço", fontsize=14)
    histplot.set_ylabel("Frequência", fontsize=14)
    plt.show()

# %%
def boxplotVisualizacao(df, titulo, xlabel):
    sns.set(style="darkgrid")
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    boxplot = sns.boxplot(data=df['Preço'], linewidth=2.5, width=0.25)
    boxplot.axes.set_title(f"Boxplot Preços dos {titulo}", fontsize=16)
    boxplot.set_xlabel(xlabel, fontsize=14)
    boxplot.set_ylabel("Preço", fontsize=14)
    plt.show()

# %%
# NOTEBOOK
plotarHistograma(df_notebook, "notebooks")

# %% [markdown]
# **Já é notorio a presença de outliers**

# %%
plotarHistograma(df_smartphone, "Smartphone")

# %%
plotarHistograma(df_smarttv, "Smart - TV")

# %% [markdown]
# ## Boxplot: Visualização de outliers

# %%
boxplotVisualizacao(df_notebook, "notebooks", "Notebooks")

# %% [markdown]
# **Percebe-se que há outliers no departamento de notebooks.**
#
# **Podem ser notebooks especiais, como gamers ou outros**
#
# **Haverá agora um trabalho de remoção de outliers do nosso dataset**

# %%
boxplotVisualizacao(df_smartphone, "smartphone", "Smartphone")

# %%
boxplotVisualizacao(df_smarttv, "smart tv", "Smart TV")

# %% [markdown]
# ## Função que retira os indices dos outliers do nosso dataframe

# %%
def outliers_indexes(df, ft):
    """ 
    Função que retorna o índice dos outliers
    Embasamento matemático:
    Amplitude Interquartil => IQR = Quartil_3 - Quartil_1
    Limite Inferior => LI = Quartil_1 - 1.5*IQR
    Limite Superior => LS = Quartil_3 + 1.5*IQR
    Todos os dados que estiverem acima do limite superior ou abaixo do limite inferior, são outliers
    """
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR = Q3 - Q1
    
    LI = Q1 - 1.5*IQR
    LS = Q3 + 1.5*IQR
    
    lista_indices = df.index[ (df[ft] < LI) | (df[ft] > LS) ]
    
    return lista_indices

# %%
# Cria-se uma lista vazia para armazenar os índices de saídas de múltiplas colunas 
# (somente caso se quisesse tirar outliers de multiplas colunas)

def outliers_index_l(df):
    index_list = []
    for feature in ["Preço", "TotalReviews"]:
        index_list.extend(outliers_indexes(df, feature))
    outliers_index_list = outliers_indexes(df, 'Preço')
    print("Quantidade de outliers: ",len(outliers_index_list))
    
    return outliers_index_list

# %% [markdown]
# ### Tratando Notebooks

# %%
outliers_index_list_notebook = outliers_index_l(df_notebook)
# Out:
# Quantidade de outliers:  11

# %% [markdown]
# ### Função de Remoção de Outliers

# %% [markdown]
# Por fim, define-se uma função para a remoção de todos os registros que contém outliers, tendo a lista de índices como input

# %%
def remove_outliers(df, index_list):
    index_list = sorted(set(index_list))
    # Drop dos outliers
    df = df.drop(index_list)
    return df

# %% [markdown]
# ### Limpa-se o dataframe dos outliers

# %%
df_clean_notebook = remove_outliers(df_notebook, outliers_index_list_notebook)

# %%
df_clean_notebook.shape
# Out:
# (339, 5)

# %% [markdown]
# Foram removidos 11 registros, exatamente como esperado

# %% [markdown]
# ## Histograma: Distribuição de Frequência (Outliers removidos)

# %%
plotarHistograma(df_clean_notebook, "notebooks")

# %% [markdown]
# **Nota que ainda existem dados com valor igual a 0**

# %%
df_clean_notebook = df_clean_notebook[df_clean_notebook["Preço"] > 1000]
plotarHistograma(df_clean_notebook, "notebooks")

# %% [markdown]
# ### Boxplt sem Outliers

# %%
boxplotVisualizacao(df_clean_notebook,"notebook","Notebook")

# %% [markdown]
# ### Estatística descritiva, sem outliers

# %%
df_clean_notebook.describe().round(2)
# Out:
#        TotalReviews    Preço
# count        315.00   315.00
# mean           7.63  3846.09
# std           23.15  1603.85
# min            0.00  1076.28
# 25%            0.00  2653.25
# 50%            0.00  3607.12
# 75%            2.50  4980.14
# max          161.00  8753.32

# %% [markdown]
# **Um interessante ponto é a distribuição de preço com um desvio padrão de 1500 R$, como geralmente é esperado, quanto melhor é a configuração maior é o preço, onde geralmente é essa a diferença**

# %% [markdown]
# ### Item mais caro (Com Outliers)

# %%
df_mask_notebook = df_notebook['Preço']==max(df_notebook['Preço'])
filtered_df = df_notebook[df_mask_notebook]
filtered_df
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 231  Notebook Dell Alienware x17 R1 AW17-X17R1-M30S...             0  33029.1
#
#                                                    Url        Loja
# 231  https://www.americanas.com.br/produto/34731980...  Americanas

# %% [markdown]
# ## Item mais caro (Sem Outliers)

# %%
df_mask_notebook = df_clean_notebook['Preço']==max(df_clean_notebook['Preço'])
filtered_df = df_clean_notebook[df_mask_notebook]
filtered_df
# Out:
#                                             Descrição  TotalReviews    Preço  \
# 31  Notebook Gamer Predator Helios 300 PH315-53-75...            22  8753.32
#
#                                                   Url        Loja
# 31  https://www.americanas.com.br/produto/29708750...  Americanas

# %% [markdown]
# ### 5 itens com preço menor ou igual a média

# %%
df_mask_notebook = df_clean_notebook['Preço']<=df_clean_notebook['Preço'].mean()
filtered_df = df_clean_notebook[df_mask_notebook]
filtered_df.sort_values(by=['Preço'], ascending=False)[:5]
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 250  Notebook Lenovo Ultrafino Ideapad 3i Intel Cor...             0  3839.00
# 141  Notebook Vaio FE14 Intel Core i5-10210u 8GB 25...             0  3799.99
# 151  Notebook Lenovo Ultrafino ideapad S145 Dual Co...             8  3789.00
# 300  Notebook Samsung Chromebook Plus Intel 4Gb 32G...             1  3759.00
# 306  Kit Notebook Dell Inspiron 3501-M41PB 15.6" HD...             0  3725.10
#
#                                                    Url        Loja
# 250  https://www.americanas.com.br/produto/35660504...  Americanas
# 141  https://www.americanas.com.br/produto/35293543...  Americanas
# 151  https://www.americanas.com.br/produto/17724621...  Americanas
# 300  https://www.americanas.com.br/produto/26434590...  Americanas
# 306  https://www.americanas.com.br/produto/37146841...  Americanas

# %% [markdown]
# ## Adicionando Modelos

# %%
objeto = "Acer"
df_clean_notebook[df_clean_notebook["Descrição"].str.lower().str.contains(objeto.lower())].head()
# Out:
#                                             Descrição  TotalReviews    Preço  \
# 6   Notebook Acer Aspire 5 A514-53-39KH Intel Core...            19  3040.02
# 15  Notebook Gamer Acer Nitro 5 AN515-54-574Q Inte...            18  4975.17
# 23  Notebook Gamer Acer Aspire Nitro AN515-43-R9K7...            42  4939.24
# 33  Notebook Acer Aspire 5 A515-54G-52C1 Intel Cor...            35  4169.55
# 35  Notebook Acer Aspire 3 Intel Celeron 4GB 1TB E...            16  2483.10
#
#                                                   Url        Loja
# 6   https://www.americanas.com.br/produto/31948572...  Americanas
# 15  https://www.americanas.com.br/produto/17880095...  Americanas
# 23  https://www.americanas.com.br/produto/18243235...  Americanas
# 33  https://www.americanas.com.br/produto/32810433...  Americanas
# 35  https://www.americanas.com.br/produto/18500941...  Americanas

# %%
modelos = ["lenovo", "positivo", "samsung", "dell", "acer", "apple" ]
count = 0
df_clean_notebook["Modelo"] = np.NaN

for index, row in df_clean_notebook.iterrows():
    for modelo in modelos:
        if modelo in row["Descrição"].lower():
            df_clean_notebook.loc[index, "Modelo"] = modelo.capitalize()

# %% [markdown]
# ## Retirando os modelos não encontrados

# %%
df_clean_notebook = df_clean_notebook[df_clean_notebook["Modelo"].notna()]
df_clean_notebook.shape
# Out:
# (245, 6)

# %% [markdown]
# ### Visualizando alguns dados utilizando o SEABORN

# %%
sns.pairplot(data=df_clean_notebook, hue="Modelo")

# %%
sns.jointplot(data=df_clean_notebook, x="Preço", y="TotalReviews", hue="Modelo", kind="hist")

# %% [markdown]
# # Tratando Smartphones

# %%
# df_smartphone

# %%
outliers_index_list_smartphone = outliers_index_l(df_smartphone)
# Out:
# Quantidade de outliers:  25

# %% [markdown]
# ### Limpar o dataframe dos outliers

# %%
df_clean_smartphone = remove_outliers(df_smartphone, outliers_index_list_smartphone)

# %%
df_clean_smartphone.shape
# Out:
# (321, 5)

# %% [markdown]
# ### Histograma: Distribuição de Frequência (Outliers removidos)

# %%
plotarHistograma(df_clean_smartphone, "smartphone")

# %%
df_clean_smartphone = df_clean_smartphone[df_clean_smartphone["Preço"] > 80]
plotarHistograma(df_clean_smartphone, "smartphone")

# %%
boxplotVisualizacao(df_clean_smartphone, "smartphone","Smartphone")

# %% [markdown]
# ### Estatística descritiva, sem outliers

# %%
df_clean_smartphone.describe().round(2)
# Out:
#        TotalReviews    Preço
# count        319.00   319.00
# mean          98.61  1410.03
# std          193.63   770.30
# min            0.00    94.05
# 25%            1.00   842.52
# 50%           13.00  1329.10
# 75%           98.00  1909.50
# max         1899.00  3704.98

# %%
# Maior Preço
df_mask_smartphone = df_clean_smartphone['Preço']==max(df_clean_smartphone['Preço'])
filtered_df = df_clean_smartphone[df_mask_smartphone]
filtered_df
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 182  Smartphone Motorola Edge 128GB 5G Wi-Fi Tela 6...            19  3704.98
#
#                                                    Url        Loja
# 182  https://www.americanas.com.br/produto/17789400...  Americanas

# %%
# 5 itens menor ou igual a média
df_mask_smartphone = df_clean_smartphone['Preço']<=df_clean_smartphone['Preço'].mean()
filtered_df = df_clean_smartphone[df_mask_smartphone]
filtered_df.sort_values(by=['Preço'], ascending=False)[:5]
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 261  Smartphone Motorola Moto E6s 32GB 4G Wi-Fi Tel...            29  1400.00
# 156  Smartphone Motorola Moto G8 Power Lite 64GB 4G...             0  1399.00
# 330  Smartphone Zenfone Max Shot Dual Chip Android ...            14  1399.00
# 167  Smartphone Motorola Moto G8 Power Lite 64GB 4G...           150  1399.00
# 39   Smartphone Samsung Galaxy M32 128GB 4G Wi-Fi T...             0  1393.16
#
#                                                    Url        Loja
# 261  https://www.americanas.com.br/produto/16507341...  Americanas
# 156  https://www.americanas.com.br/produto/16544931...  Americanas
# 330  https://www.americanas.com.br/produto/13429675...  Americanas
# 167  https://www.americanas.com.br/produto/16502182...  Americanas
# 39   https://www.americanas.com.br/produto/35011674...  Americanas

# %% [markdown]
# ## Adicionar modelos Smartphone

# %%
objeto = "asus"
df_clean_smartphone[df_clean_smartphone["Descrição"].str.lower().str.contains(objeto.lower())].head()
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 53   Smartphone asus Zenfone Max Pro M2, 6GB ram, 6...            10   881.39
# 161  Smartphone Asus Zenfone Max Shot 3GB-32GB, Tel...            11   781.08
# 234  Smartphone Asus Zenfone Max Shot 32GB 12MP Tel...             0   781.08
# 247  Smartphone Zenfone Asus Max Shot 64 GB Dual Ch...            73  1085.00
# 332  Celular Asus Zenfone Live L2 Dourado Rose 32GB...            22  1598.00
#
#                                                    Url        Loja
# 53   https://www.americanas.com.br/produto/38663009...  Americanas
# 161  https://www.americanas.com.br/produto/13295745...  Americanas
# 234  https://www.americanas.com.br/produto/35567935...  Americanas
# 247  https://www.americanas.com.br/produto/13421918...  Americanas
# 332  https://www.americanas.com.br/produto/15369973...  Americanas

# %%
modelos = ["samsung", "apple", "motorola", "asus", "xiaomi ", "lg", "moto" ]
count = 0
df_clean_smartphone["Modelo"] = np.NaN

for index, row in df_clean_smartphone.iterrows():
    for modelo in modelos:
        if modelo in row["Descrição"].lower():
            df_clean_smartphone.loc[index, "Modelo"] = modelo.capitalize()

# %% [markdown]
# ## Retirando os modelos não encontrados

# %%
df_clean_smartphone = df_clean_smartphone[df_clean_smartphone["Modelo"].notna()]
df_clean_smartphone.shape
# Out:
# (246, 6)

# %%
sns.pairplot(data=df_clean_smartphone, hue="Modelo")

# %% [markdown]
# ## Tratando Smart TV

# %%
## df_smartphone
outliers_index_list_smarttv = outliers_index_l(df_smarttv)
df_clean_smartTV = remove_outliers(df_smarttv, outliers_index_list_smarttv)
df_clean_smartTV.shape
# Out:
# Quantidade de outliers:  38
# (311, 5)

# %% [markdown]
# ## Histograma: Distribuição de Frequência (Outliers removidos)

# %%
plotarHistograma(df_clean_smartTV, "Smart TV")

# %%
df_clean_smartTV = df_clean_smartTV[df_clean_smartTV["Preço"] > 500]
plotarHistograma(df_clean_smartTV, "smart tv")

# %%
boxplotVisualizacao(df_clean_smartTV, "smart tv","Smart TV")

# %% [markdown]
# ## Adicionando modelos

# %%
modelos = ["samsung", "lg", "sony", "tcl", "philips", "apple", "philco" ]
count = 0
df_clean_smartTV["Modelo"] = np.NaN

for index, row in df_clean_smartTV.iterrows():
    for modelo in modelos:
        if modelo in row["Descrição"].lower():
            df_clean_smartTV.loc[index, "Modelo"] = modelo.capitalize()

# %%
df_clean_smartTV = df_clean_smartTV[df_clean_smartTV["Modelo"].notna()]
df_clean_smartTV.shape
# Out:
# (226, 6)

# %% [markdown]
# ## Visualizando dados

# %%
sns.pairplot(data=df_clean_smartTV, hue="Modelo")

# %%
sns.jointplot(data=df_clean_smartTV, x="Preço", y="TotalReviews", hue="Modelo", kind="hist")

# %% [markdown]
# # Adicionar geladeira

# %%
df_geladeira= pd.read_csv("./output/dataset_geladeira.csv", sep=";")
df_geladeira.count()
# Out:
# Descrição       350
# TotalReviews    350
# Preço           350
# Url             350
# Loja            350
# dtype: int64

# %%
df_geladeira.head()
# Out:
#                                            Descrição  TotalReviews    Preço  \
# 0  Geladeira / Refrigerador Brastemp Duplex BRM44...           585  2499.99
# 1  Geladeira Brastemp BRM44HK Frost Free Duplex 3...           584  2899.99
# 2  Geladeira/Refrigerador Electrolux DC35A Branca...           253  1789.99
# 3  Refrigerador Electrolux 1 Porta RE31 240 Litro...           150  1368.99
# 4  Geladeira/Refrigerador Electrolux French Door ...           293  6199.99
#
#                                                  Url        Loja
# 0  https://www.americanas.com.br/produto/13325734...  Americanas
# 1  https://www.americanas.com.br/produto/13360572...  Americanas
# 2  https://www.americanas.com.br/produto/11195745...  Americanas
# 3  https://www.americanas.com.br/produto/11195748...  Americanas
# 4  https://www.americanas.com.br/produto/13323316...  Americanas

# %%
print("Valores nulos geladeiras: ", df_geladeira.isnull().sum().sum())
# Out:
# Valores nulos geladeiras:  0

# %%
df_geladeira.describe().round(2)
# Out:
#        TotalReviews     Preço
# count        350.00    350.00
# mean          21.93   3306.55
# std           68.70   3939.62
# min            0.00      0.00
# 25%            0.00    208.24
# 50%            0.00   2855.16
# 75%            4.00   4189.25
# max          585.00  30999.00

# %% [markdown]
# **Remover os preços iguais a 0**

# %%
print("Visualizando dado smartphone preço == 0")
df_geladeira.query("Preço == 0")
# Out:
# Visualizando dado smartphone preço == 0
#                                              Descrição  TotalReviews  Preço  \
# 146  Refrigerador Panasonic NR-BT40BD1XB 387L Aço E...             1    0.0
# 168  Refrigerador Panasonic NR-BB53GV3WAB 425L Whit...             1    0.0
#
#                                                    Url        Loja
# 146  https://www.americanas.com.br/produto/21349361...  Americanas
# 168  https://www.americanas.com.br/produto/24495941...  Americanas

# %%
plotarHistograma(df_geladeira, "Geladeira")

# %% [markdown]
# **Muitos outliners**

# %%
boxplotVisualizacao(df_geladeira, "Geladeira", "Geladeira")

# %% [markdown]
# ### Removendo outliners Geladeira

# %%
outliers_index_list_geladeira = outliers_index_l(df_geladeira)
df_clean_geladeira = remove_outliers(df_geladeira, outliers_index_list_geladeira)
# Out:
# Quantidade de outliers:  19

# %%
plotarHistograma(df_clean_geladeira, "geladeira")

# %%
# Definindo um preço mínimo pra geladeiras de 700 reais
df_clean_geladeira = df_clean_geladeira[df_clean_geladeira["Preço"] > 700]
plotarHistograma(df_clean_geladeira, "notebooks")

# %%
boxplotVisualizacao(df_clean_geladeira,"geladeira","Geladeira")

# %%
df_mask_geladeira = df_clean_geladeira['Preço']<=df_clean_geladeira['Preço'].mean()
filtered_df = df_clean_geladeira[df_mask_geladeira]
filtered_df.sort_values(by=['Preço'], ascending=False)[:5]
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 200  Refrigerador Electrolux Inverter 431 Litros Pl...             0  3721.90
# 44   Geladeira/Refrigerador Electrolux Frost Free B...            29  3699.99
# 65   Refrigerador Panasonic BB53 Inverter Bottom Fr...             2  3699.98
# 75   Geladeira/Refrigerador Samsung Duplex RT38K5A0...            21  3698.99
# 96   Refrigerador Duplex Electrolux 474 Litros Fros...             3  3697.14
#
#                                                    Url        Loja
# 200  https://www.americanas.com.br/produto/19184669...  Americanas
# 44   https://www.americanas.com.br/produto/28547544...  Americanas
# 65   https://www.americanas.com.br/produto/30293104...  Americanas
# 75   https://www.americanas.com.br/produto/24925406...  Americanas
# 96   https://www.americanas.com.br/produto/31206398...  Americanas

# %%
df_clean_geladeira["Modelo"] = np.NaN

# %%
df_clean_geladeira
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 0    Geladeira / Refrigerador Brastemp Duplex BRM44...           585  2499.99
# 1    Geladeira Brastemp BRM44HK Frost Free Duplex 3...           584  2899.99
# 2    Geladeira/Refrigerador Electrolux DC35A Branca...           253  1789.99
# 3    Refrigerador Electrolux 1 Porta RE31 240 Litro...           150  1368.99
# 4    Geladeira/Refrigerador Electrolux French Door ...           293  6199.99
# ..                                                 ...           ...      ...
# 300                           Refrigerador Ngv 10 Azul             0  1699.00
# 305  Refrigerador Panasonic BT40 387L 2 Portas Bran...             0  2751.14
# 323  Refrigerador Consul CRA30F com Degelo Seco e G...             0  1529.00
# 326  Refrigerador Brastemp Inverse 419L 3 Portas Fr...             0  6449.14
# 346  Refrigerador Consul Domest 1 Porta 342 Litros ...             0  1898.99
#
# ...

# %% [markdown]
# # Todos os dataframes

# %%
#df_clean_notebook
#df_clean_smartphone
#df_clean_smartTV
#df_clean_geladeira

# %%
df_clean_notebook["Categoria"] = "Notebook"
df_clean_smartphone["Categoria"] = "Smartphone"
df_clean_smartTV["Categoria"] = "Televisão"
df_clean_geladeira["Categoria"] = "Geladeira"

# %%
df_clean_geladeira.head()
# Out:
#                                            Descrição  TotalReviews    Preço  \
# 0  Geladeira / Refrigerador Brastemp Duplex BRM44...           585  2499.99
# 1  Geladeira Brastemp BRM44HK Frost Free Duplex 3...           584  2899.99
# 2  Geladeira/Refrigerador Electrolux DC35A Branca...           253  1789.99
# 3  Refrigerador Electrolux 1 Porta RE31 240 Litro...           150  1368.99
# 4  Geladeira/Refrigerador Electrolux French Door ...           293  6199.99
#
#                                                  Url        Loja  Modelo  \
# 0  https://www.americanas.com.br/produto/13325734...  Americanas     NaN
# 1  https://www.americanas.com.br/produto/13360572...  Americanas     NaN
# 2  https://www.americanas.com.br/produto/11195745...  Americanas     NaN
# 3  https://www.americanas.com.br/produto/11195748...  Americanas     NaN
# 4  https://www.americanas.com.br/produto/13323316...  Americanas     NaN
#
#    Categoria
# 0  Geladeira
# 1  Geladeira
# 2  Geladeira
# ...

# %%
data_frame_geral = pd.concat([df_clean_notebook, df_clean_smartphone, df_clean_smartTV, df_clean_geladeira], ignore_index=True)

# %%
pd.to_csv
# Out:
#                                              Descrição  TotalReviews    Preço  \
# 0    Notebook Lenovo Ultrafino Ideapad 3i Intel Cor...            54  3562.49
# 1    Notebook Samsung Book Intel Celeron-6305 4GB 5...            90  2098.70
# 2    Notebook Lenovo Ultrafino Ideapad S145 AMD Ryz...             7  2952.57
# 3    Notebook Samsung Book Intel Core i5-1135G7 8GB...             0  3544.81
# 4    Notebook Positivo Motion Q464C Intel Atom Z835...            73  1424.99
# ..                                                 ...           ...      ...
# 933                           Refrigerador Ngv 10 Azul             0  1699.00
# 934  Refrigerador Panasonic BT40 387L 2 Portas Bran...             0  2751.14
# 935  Refrigerador Consul CRA30F com Degelo Seco e G...             0  1529.00
# 936  Refrigerador Brastemp Inverse 419L 3 Portas Fr...             0  6449.14
# 937  Refrigerador Consul Domest 1 Porta 342 Litros ...             0  1898.99
#
# ...
